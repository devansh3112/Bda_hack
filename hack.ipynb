# %%
import pandas as pd

# Load the dataset from the specified path
file_path = r'C:\Users\devan\bda_hack\INSTAGRAM_REVIEWS.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#    Unnamed: 0                             review_id       pseudo_author_id  \
# 0           0  ff25650a-a9e1-4c02-a8e8-0c85b9ee1dc9  127325963209728431078
# 1           1  7e1840fe-4307-4c97-974c-437ec6c64e60  148177168797697591284
# 2           2  3c8ba6fc-3009-4b1c-9a24-9ea635799a9a  162050472706594017332
# 3           3  47c54668-dbac-4f8f-a98a-3ede00a103ea  264067006274581079256
# 4           4  464a6a51-9a9f-44b0-80b5-eeea24adcd57  224172402296862948810
#
#            author_name                                        review_text  \
# 0             B ****or  Used this app for years. Was a great way to es...
# 1          مس*******لو                                 khayemalo sag bgad
# 2         Li********on                                             Lovely
# 3           Fa******Zx                                               best
# 4  fr***************67                                              Super
#
#    review_rating  review_likes author_app_version     review_timestamp
# 0              1             0     216.1.0.21.137  2022-01-05 23:37:15
# 1              5             0     155.0.0.37.107  2022-01-05 23:39:29
# 2              5             0                NaN  2022-01-05 23:39:32
# 3              5             0                NaN  2022-01-05 23:39:50
# 4              5             0     216.0.0.20.137  2022-01-05 23:40:08

# %%
# -------------------------------------------
# Use this if you have an error about the SSL
# import ssl
# ssl._create_default_https_context = ssl._create_unverified_context
# -------------------------------------------

import nltk
# -----------------------
# Used when first run
# nltk.download('wordnet')
# nltk.download('stopwords')
# -----------------------

import pandas as pd
import re
import string

from langdetect import detect
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import ComplementNB
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer

from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
stop_words = stopwords.words()

from collections import Counter

# %%
data = pd.read_csv(r'C:\Users\devan\bda_hack\INSTAGRAM_REVIEWS.csv')

# remove unused column
data.drop([ 
            "review_id", 
            "pseudo_author_id",
            "author_name",
            "review_likes",
            "author_app_version",
            "review_timestamp",
          ], inplace=True, axis=1)

#  change column name
data.rename(columns={'review_text': 'text'}, inplace=True)
data.rename(columns={'review_rating': 'sentiment'}, inplace=True)

#  save to new file
data.to_csv('dataset_cleaned_1.csv', index=False)

# %%
def remove_numbers(text):
    if isinstance(text, str):
        return ''.join(char for char in text if not char.isdigit())
    else:
        return text

def remove_character(text):
    if isinstance(text, str):  # checks if a string value exists
        text = text.lower()  # converting to lowercase
        text = re.sub('https?://\S+|www\.\S+', '', text)  # removing URL links
        text = re.sub(r"\b\d+\b", "", text)  # removing number
        text = re.sub('<.*?>+', '', text)  # removing special characters
        text = re.sub('[%s]' % re.escape(string.punctuation), '', text)  # punctuations
        text = re.sub('\n', '', text)
        text = re.sub('[’“”…]', '', text)
        return text
    else:
        return text

def remove_emoji(text):
    if isinstance(text, str):
        emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F700-\U0001F77F"  # alchemical symbols
                           u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                           u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                           u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                           u"\U0001FA00-\U0001FA6F"  # Chess Symbols
                           u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                           u"\U00002702-\U000027B0"  # Dingbats
                           u"\U000024C2-\U0001F251" 
                           "]+", flags=re.UNICODE)
        return emoji_pattern.sub(r'', text)
    else:
        return text


def remove_short_form(text):
    if isinstance(text, str):
        # removing short form:
        text = re.sub("isn't", 'is not', text)
        text = re.sub("he's", 'he is', text)
        text = re.sub("wasn't", 'was not', text)
        text = re.sub("there's", 'there is', text)
        text = re.sub("couldn't", 'could not', text)
        text = re.sub("won't", 'will not', text)
        text = re.sub("they're", 'they are', text)
        text = re.sub("she's", 'she is', text)
        text = re.sub("There's", 'there is', text)
        text = re.sub("wouldn't", 'would not', text)
        text = re.sub("haven't", 'have not', text)
        text = re.sub("That's", 'That is', text)
        text = re.sub("you've", 'you have', text)
        text = re.sub("He's", 'He is', text)
        text = re.sub("what's", 'what is', text)
        text = re.sub("weren't", 'were not', text)
        text = re.sub("we're", 'we are', text)
        text = re.sub("hasn't", 'has not', text)
        text = re.sub("you'd", 'you would', text)
        text = re.sub("shouldn't", 'should not', text)
        text = re.sub("let's", 'let us', text)
        text = re.sub("they've", 'they have', text)
        text = re.sub("You'll", 'You will', text)
        text = re.sub("i'm", 'i am', text)
        text = re.sub("we've", 'we have', text)
        text = re.sub("it's", 'it is', text)
        text = re.sub("don't", 'do not', text)
        text = re.sub("that´s", 'that is', text)
        text = re.sub("I´m", 'I am', text)
        text = re.sub("it’s", 'it is', text)
        text = re.sub("she´s", 'she is', text)
        text = re.sub("he’s'", 'he is', text)
        text = re.sub('I’m', 'I am', text)
        text = re.sub('I’d', 'I did', text)
        text = re.sub("he’s'", 'he is', text)
        text = re.sub('there’s','there is',text)
        return text
    else:
        return text
    
def remove_multiple_space(text):
    if isinstance(text, str):
        text = text.strip()
        text = re.sub(r'\s+', ' ', text)
        return text
    else:
        return text


def detect_english(text):
    try:
        return detect(text) == 'en'
    except Exception as e:
        print(f"Error detecting language: {e} - {text}")
        return False
    
cnt = Counter()
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
def remove_freqwords(text):
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])

# %%
# remove number
data = pd.read_csv('dataset_cleaned_1.csv')
data['text'] = data['text'].apply(remove_numbers)
data.to_csv('dataset_cleaned_2.csv', index=False)

# %%
data = pd.read_csv('dataset_cleaned_2.csv')
data['text'] = data['text'].apply(remove_character)
data.to_csv('dataset_cleaned_3.csv', index=False)

# %%
# remove emoji
data = pd.read_csv('dataset_cleaned_3.csv')
data['text'] = data['text'].apply(remove_emoji)
data.to_csv('dataset_cleaned_4.csv', index=False)

# %%
# remove short form
data = pd.read_csv('dataset_cleaned_4.csv')
data['text'] = data['text'].apply(remove_short_form)
data.to_csv('dataset_cleaned_5.csv', index=False)

# %%
# remove multiple space
data = pd.read_csv('dataset_cleaned_5.csv')
data['text'] = data['text'].apply(remove_multiple_space)
data.to_csv('dataset_cleaned_6.csv', index=False)

# %%
# remove empty record and duplicate data
data = pd.read_csv('dataset_cleaned_6.csv')
data.drop_duplicates(inplace=True)
data.dropna(inplace=True)
data.to_csv('dataset_cleaned_7.csv', index=False)

# %%
# remove record non-english
data = pd.read_csv('dataset_cleaned_7.csv')
data['is_english'] = data['text'].apply(detect_english)
data = data[data['is_english']]
data = data.drop(columns=['is_english'])
data.to_csv('dataset_cleaned_8.csv', index=False)
# Out:
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴠᴇʀy ɴɪᴄᴇ ᴀᴩᴩ
# Error detecting language: No features in text. - ရတနာ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - tʜᴇ ʙᴇsᴛ ᴀᴘᴘ
# Error detecting language: No features in text. - စပီးပေးတာတကယ်မကောင်းဘူး
# Error detecting language: No features in text. - ฅ••ฅ
# Error detecting language: No features in text. - អូន និច
# Error detecting language: No features in text. - yᑌᗩᖇ iᑎտtᗩᖇᗩᑎ ᑎot ᖇᗴᗴᒪտ ᕼᗩᐯᗴ ᑭᗩᖇoᗰᗷᗩᒪ տoᒪ ᑭᗩᒪiտտ
# Error detecting language: No features in text. - sᕼᗩᐯeᒍ ᑕᕼ
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - බෙස්ට්
# Error detecting language: No features in text. - ႁၵ်ႉ
# Error detecting language: No features in text. - ဝပဲဓသြဝ
# Error detecting language: No features in text. - i ᴅᴏɴᴛ ʟɪᴋᴇ ᴛʜɪs ᴀᴘᴘ ʙᴇᴀᴄᴜsᴇ ɪ ᴅᴏɴᴛ ʜᴀᴠᴇ ʀᴇᴘʟʏ ᴏᴘᴛɪᴏɴ ᴀɴᴅ ɪ ʀᴇᴘᴏʀᴛ ᴛʜᴇʀ ᴀ ᴘʀᴏʙʟᴇᴍ ᴛʜᴀʏ ɴᴏᴛ sᴏʟᴠᴇ ɪᴛ
# Error detecting language: No features in text. - ខ្ញុំចូលចិត្ត
# Error detecting language: No features in text. - ʜᴇʟʟᴏ
# Error detecting language: No features in text. - sᴜᴘᴀʀ
# Error detecting language: No features in text. - ၾကယ္ ငါးပြင့္ေပးတယ္
# Error detecting language: No features in text. - ល្អបំផុតសម្រាប់អ្នកប្រើប្រាស់
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - °∆°
# Error detecting language: No features in text. - පට්ටැහ්
# Error detecting language: No features in text. - အမ
# Error detecting language: No features in text. - රුවන්
# Error detecting language: No features in text. - ʙᴀʜᴏᴛ
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ‌‌‌‌‌
# Error detecting language: No features in text. - យយយយយយយយយុុុយយយយុយយ។ ដចវងងវថរររេេេេត្កយហតង្ហហហនហហង។
# Error detecting language: No features in text. - i ғᴏᴜɴᴅ ᴍʏ ʟᴏᴠʀ
# Error detecting language: No features in text. - ထုိင္းစကားေလလာက်မယ္
# Error detecting language: No features in text. - tʜɪs ɪs ᴀ ᴠᴇʀʏ ɴɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᭄༆
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - အကောင့်မဖွင်တက်ဘူး
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ₹₹
# Error detecting language: No features in text. - ်ြ့်ု့ူကု
# Error detecting language: No features in text. - ၼွင်ၼူၼ်း
# Error detecting language: No features in text. - သႏၱာႏွင္​း
# Error detecting language: No features in text. - gᖴᗪᑎᗷ ᐯᗷᖇᒍt ᘔᐯᗪᗷᗰᖇᑎᕼ ᖴᗯᖇᕼᑫtᗩ
# Error detecting language: No features in text. - ℕ ℝ ℍ
# Error detecting language: No features in text. - •¡
# Error detecting language: No features in text. - ¯¯
# Error detecting language: No features in text. - ɢᴏᴏᴅ ᴀᴩᴩ
# Error detecting language: No features in text. - ɪ yᴏᴜ ᴀʀᴇ ʙᴀᴅ ɪ yᴏᴜʀ ᴅᴀᴅ
# Error detecting language: No features in text. - ๛›ᴹʀ᭄¿ᴮᴬᴰʙᴏy࿐
# Error detecting language: No features in text. - aᴡᴇsᴏᴍᴇ
# Error detecting language: No features in text. - ଆପ ଟା ଭଲ ଅଛି ଆଉ ଟିକେ ଭଲ ହେଇ ଥାନ୍ତା କାରଣ ଜାଣିନି
# Error detecting language: No features in text. - ᴡʜᴀᴛ ᴀ ᴀʙᴜʟᴏᴜ ᴀᴩᴩ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - မိုက်
# Error detecting language: No features in text. - ⁿʸˣ
# Error detecting language: No features in text. - ሸሸ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - kₐᵣₐ
# Error detecting language: No features in text. - ᴠᴇʀʏ ɴɪᴄᴇ
# Error detecting language: No features in text. - ʙᴇᴛ ᴀᴩᴩ
# Error detecting language: No features in text. - ⁿⁱᶜᵉ
# Error detecting language: No features in text. - ល្អ
# Error detecting language: No features in text. - ၾကာလိုက္တာ ရပါမလား
# Error detecting language: No features in text. - បង
# Error detecting language: No features in text. - ᴋ ɢᴀᴍɪɴɢ ᴛʜᴀᴋᴜʀ
# Error detecting language: No features in text. - ʋɛʀʏ ռɨƈɛ ǟքք
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴠᴇᴛ ᴀᴩᴩ ɪ ᴅɪᴅ ɴᴏᴛ ʟɪᴋᴇ ᴛʜɪ ᴀᴩᴩ
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - ᗷᗴտt
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ទន្សាយ
# Error detecting language: No features in text. - nɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - meကြိုက်တယ်သုံန်လိုကောင်နေတာပဲ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - ါြ်ကပင
# Error detecting language: No features in text. - ɢɢᴏᴏᴅ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ℙℙ
# Error detecting language: No features in text. - ការសិក្សាអំពីភាសា
# Error detecting language: No features in text. - ℙ
# Error detecting language: No features in text. - တရုတ္မေလး
# Error detecting language: No features in text. - ស៊ីនិង័ិឥុហកុ
# Error detecting language: No features in text. - ʟᴏᴠᴇʟʏ ᴀᴘᴘ
# Error detecting language: No features in text. - នេះជាកម្មវិធីដែលល្អ
# Error detecting language: No features in text. - ᴛʜɪ ᴀᴩᴩ ɪ ɢᴏᴏᴅ ʙᴜᴛ ᴅᴏ ɴᴏᴛ ᴜᴇ ᴀɴyᴛɪᴍᴇ ᴀᴠᴇʀyᴠᴇᴀʀ ʙᴇᴄᴀᴜᴇ ᴛʜɪ ᴀᴩᴩ ɪ ɪᴍᴩʀᴀᴛᴀᴛɪᴏɴ ɪɴ yᴏᴜ ʟɪᴇ yᴏᴜ ᴛɪᴍᴇ ᴛᴀʙʟᴇ yᴏᴜ ʟᴀɴɢᴜᴀɢᴇ yᴏᴜ ᴇyᴇ ᴀɴᴅ yᴏᴜʀ ʜᴇᴀʟᴛʜ ᴋᴇᴇᴩ ᴜᴇ ʜᴀʟ ᴀɴᴅ ʜᴏᴠʀᴇ ʙᴜᴛ ᴛʜᴇɴ ʜᴏᴜʀ ᴍᴇ ᴇ ʜɪ ɢʜᴀɴᴛᴇ ᴄʜᴀʟᴇyᴇ ᴛᴀy ᴀᴇ ᴅᴜʀɪɴɢ ᴄᴏᴠɪᴅ ᴠɪʀᴜ ᴋᴇᴇᴩ ᴍᴀᴋ ᴏɴ ᴄᴏʀᴏɴᴀ ɢᴏɴᴇ
# Error detecting language: No features in text. - ↕↔↕
# Error detecting language: No features in text. - គន្ធា
# Error detecting language: No features in text. - sᴜᴘᴘ
# Error detecting language: No features in text. - իṫℍṳ₦ḑℰℛ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ផា ស្រីអូន
# Error detecting language: No features in text. - ហាយ
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ᴛʜɪs ᴀᴘᴘ ɪs ɴɪᴄᴇ ʙᴜᴛ ᴍʏ ғʀɪᴇɴᴅ ʜᴀᴠᴇ sᴏᴍᴇ ғᴇᴀᴛᴜʀᴇs ʙᴜᴛ ɪ ᴅᴏɴᴛ ʜᴀᴠᴇ ᴛʜᴛᴀ ғᴇᴀᴛᴜʀᴇs ᴛʜᴀᴛs ᴡʜʏ ɪ ɢᴀᴠᴇ sᴛᴀʀ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - အိအိ
# Error detecting language: No features in text. - gᴏᴏᴅ ᴀᴀᴘ
# Error detecting language: No features in text. - ᴏᴋ
# Error detecting language: No features in text. - ɪ ʟɪᴋᴇ ᴛʜɪ ᴀᴩᴩ ᴍy ᴀᴛ ʟᴀʀɪɴɢ
# Error detecting language: No features in text. - 󠁧󠁢󠁷󠁬󠁳󠁿
# Error detecting language: No features in text. - ិតថហិិិតតត ្បតតយុ្្ហយង
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ତଥଥ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɴᴏ ᴡᴏʀᴅ
# Error detecting language: No features in text. - ℴℴ
# Error detecting language: No features in text. - ʜɪ ɴᴇᴡ ᴩᴜɴᴊᴀʙɪ ᴏɴɢ ᴏʟᴩ ᴋᴀʀᴏ ʜᴀʟᴩ ᴍᴇ
# Error detecting language: No features in text. - ᴛʜɪ ɪ ᴜᴩᴇʀ ᴀᴩᴩʟɪᴄᴀʜᴀɴ ᴏɴ ɪɴᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - ኢክራም
# Error detecting language: No features in text. - ល្អ
# Error detecting language: No features in text. - በጣምደስይላል
# Error detecting language: No features in text. - •‿••‿•
# Error detecting language: No features in text. - ကျောင်းဘဋ့
# Error detecting language: No features in text. - ᴏᴘ ᴏᴘ
# Error detecting language: No features in text. - mli d´∀´∀´∀´∀´∀⌒⌒⌒⌒
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℤℕ
# Error detecting language: No features in text. - ហ ់ុ
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - ‼
# Error detecting language: No features in text. - ɴɪᴄᴇ ᴀᴩᴩ
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ិិុុុុដៀឥដថហ្កលរ
# Error detecting language: No features in text. - ⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣⃣a
# Error detecting language: No features in text. - እ ሎቭኤ ት
# Error detecting language: No features in text. - ြပပ
# Error detecting language: No features in text. - သုိက္ဆာန္သုိက္ဆာန္
# Error detecting language: No features in text. - ଇଈ
# Error detecting language: No features in text. - i ᴜsᴇ ɪɴsᴛᴀɢʀᴀᴍ ғᴏʀ ᴛᴀᴋɪɴɢ ᴘɪᴄᴛᴜʀᴇs ᴏɴʟʏɴᴏᴛʜɪɴɢ ᴇʟsᴇ
# Error detecting language: No features in text. - ពីមុននិងឥឡូវមិនដូចគ្នាទេហ
# Error detecting language: No features in text. - ᥬ᭄
# Error detecting language: No features in text. - မဆိုးပါဘူး
# Error detecting language: No features in text. - ̲̲̅̅⃝̲̲̲̅̅̅⃟̲̲̲̲̅̅ͥ̅̅͟⋆̲̲̅ͣ̅⋆̲̲̲̲̅ͫ̅̅̅l̲̅a̲̅d̲̅l̲̅a̲̲̲̅̅̅⃝̲̅​̲̲̅̅⃝̲̲̲̲̲̲̲̅̅̅̅̅̅̅͢⃟̲̲̲̲̲̲̅̅̅̅̅̅͢͟͞ ̲̲̲̅̅̅
# Error detecting language: No features in text. - ဘဘ
# Error detecting language: No features in text. - ᴋᴀʀᴋɪᴊɪ
# Error detecting language: No features in text. - no ᴄᴜᴍᴍᴜɴɪᴛʏ ɢᴜɪᴅᴇɴᴇs ᴘʟᴇᴀsᴇ
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - စာ သာ အ လြက္ ေလ တင္ ေပ ပါ လာ
# Error detecting language: No features in text. - ⊂⊃
# Error detecting language: No features in text. - ᴘʟᴇᴀsᴇ ɢᴇᴛ ғᴏʟʟᴏᴡᴇʀs ᴀɴᴅ ʟɪᴋᴇs ɪᴅ ᴍʀ ʜᴀᴛᴇʀ
# Error detecting language: No features in text. - ស៊ី សារ
# Error detecting language: No features in text. - »
# Error detecting language: No features in text. - ʜʜʜ
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - nice •ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ••ᴗ•
# Error detecting language: No features in text. - vᴇʀʏ ɴɪᴄᴇ ᴀɴᴅ ғᴀʙʟᴏᴜs ᴀᴘᴘ ɪᴛ ᴘʀᴏᴠɪᴅᴇs ᴜs ᴛᴏ ᴛᴀʟᴋ ᴛᴏ ʏᴏᴜʀ ɢғ ᴛᴏ ɢғɪs ᴀʟsᴏ ɢɪᴠᴇs ᴜᴀ ᴀ ʜᴇᴀʀᴛ ʙʀᴏᴋᴇ ᴡʜɪʟᴇ sᴏᴍᴇ ɢɪʀʟs ᴅᴏɴᴛ ᴀᴄᴄᴇᴘᴛ ᴏᴜʀ ʀᴇǫᴜᴇsᴛ
# Error detecting language: No features in text. - ₩₩
# Error detecting language: No features in text. - i ʟɪᴋᴇ ᴛʜɪs ɪɴsᴛᴀɢʀᴀᴍ࿐
# Error detecting language: No features in text. - හොඳම
# Error detecting language: No features in text. - පයිය
# Error detecting language: No features in text. - fʀᴇᴇ ғɪʀᴇ ᴜʏɪʀ pᴀᴛʜᴀɴɴᴀᴍᴛʜɪᴛᴛᴀᴋᴀʀᴀɴ kɪʟʟᴀᴅɪ ᴋᴀᴋɪʟʟᴀᴅɪ
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ᴘsʏᴄʜᴏ ᴛᴏᴍ
# Error detecting language: No features in text. - iᴛs ᴠᴇʀʏ ɢᴏᴏᴅ ғᴏʀ ᴛɪᴍᴇ ᴘᴀss ᴀᴛ ғʀᴇᴇ ᴛɪᴍᴇᴇ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - သုံးလို့​ကောင်း​တေ
# Error detecting language: No features in text. - ɢᴏᴏᴅ ʙᴜᴛ ᴇ ᴩʀᴏʙʟᴇᴍ
# Error detecting language: No features in text. - ᴘʟᴢ ɴᴏᴛ ᴜsᴇ ᴛʜᴇ sᴛᴜᴅᴇɴᴛ
# Error detecting language: No features in text. - ။။။။
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ឲោលិលេលិរ៉ិឥ
# Error detecting language: No features in text. - အေကာင္းဆံုးအပ္
# Error detecting language: No features in text. - ‼
# Error detecting language: No features in text. - យាតយុង
# Error detecting language: No features in text. - ɴɪᴄᴇ ᴀᴩᴩ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɪᴛ ᴏ ɴɪᴄᴇ ᴀɴᴅ ɢᴏᴏᴅᴅ ᴀᴘᴘᴘ
# Error detecting language: No features in text. - ကောင်းမှကောင်း
# Error detecting language: No features in text. - ᴇɴᴛᴇʀᴛᴀɪɴᴍᴇɴᴛ
# Error detecting language: No features in text. - ͡ ͡° ͜ ʖ ͡ ͡°
# Error detecting language: No features in text. - tʜɪs ᴀᴘᴘ ɪs ᴠᴇʀʏ ᴜsᴇғᴜʟ
# Error detecting language: No features in text. - ʟᴏᴠᴇ ᴛʜɪs
# Error detecting language: No features in text. - ᴏᴩᴀʀᴍᴀɴ
# Error detecting language: No features in text. - କାନେ କହିବି ତାହା କିଏ ଜାଣେ ନାହିଁ
# Error detecting language: No features in text. - ြ်ထထမ်
# Error detecting language: No features in text. - ℐℊ ℯ ℊℴℴ
# Error detecting language: No features in text. - ɴɪᴄᴄᴠᴄᴄᴄᴄᴠᴠᴠᴠᴠᴠᴠᴄᴄᴄᴄᴄᴄ
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ုထူူုပိအင္ပပ့့့ပ့့ပပပပပ့ပပပ့ကကက​ြ​ြပြပကကကကပပပ့့့့့့့ပပပပပပပပပပပပပပပပပပးးးးးးးးးးးးးးးးးးးးးးးးးးးါ်းးးးးးးးးးးးးးးး ​ြကြ​ြင
# Error detecting language: No features in text. - កផកិោម្កហលក
# Error detecting language: No features in text. - យ៉ា
# Error detecting language: No features in text. - ᴜᴩᴇʀ
# Error detecting language: No features in text. - ᴡᴇʀy ɴɪᴄᴇ ᴀᴩᴩ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ᴀʙʜɪ ᴀʀyᴀɴ
# Error detecting language: No features in text. - i ʟᴏᴠᴇ ɪᴛ
# Error detecting language: No features in text. - ɪ ʟᴏᴠᴇ ɪɴsᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - nɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ោោកកកិ
# Error detecting language: No features in text. - កាមេរ៉ា
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ܔ ᴘʀᴏܔɢᴀɴɢᴛᴀʀ•
# Error detecting language: No features in text. - super €€€€€€€€€€€€€€€€₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¡¤¡¤¡¤¡¤¡¤¤¡¤¡¤¤¡¤¡¤¡¤¤¡¤¤¤¡¤¤¡¤¤¤¤¤¤¤¤¤¤¤¡¤¤¤¤¡¡¡¡¡¡¡¡¡¡¤¤¡
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - °᭄ᶫᵒᵛᵉᵧₒᵤ࿐
# Error detecting language: No features in text. - ସୁପର୍
# Error detecting language: No features in text. - ɪᴛs ᴡᴀʏ ᴛᴏᴏ ᴀᴡᴇsᴏᴍᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴀʟʟ ᴇᴛᴜᴩ ɪ ɢᴏᴏᴅ ʙᴜᴛ ᴍy ʟᴏᴡᴇʀ ɪ ɴᴏᴛ ɪɴᴄʀᴇ
# Error detecting language: No features in text. - ල ි
# Error detecting language: No features in text. - ɪ ɢɪᴠᴇ sᴛᴀʀ ʙᴇᴄᴏᴢ ᴡʜᴇɴ ɪ ʟᴏɢɪɴ ᴛʜᴇʏ sᴀʏs tʀʏ ᴀɢᴀɪɴ ʟᴀᴛᴇʀ ᴀɴᴅ ᴛʜᴇɴ ᴛʜᴇɴᴛʜᴇɴ ᴀᴡᴀʏs ᴛʀʏ ᴀɢᴀɪɴ ʟᴀᴛᴇʀ ᴡʜᴇɴ ɪ ʟᴏɢɪɴ ғʙ ɪᴛs ʟᴏɢɪɴ ʙᴜᴛ ɪ ɢᴏɴᴇ ᴍʏ ᴋ ғᴏʟʟᴏᴡᴇʀs ɪᴅ ᴍʏ ɪᴅ dcpokemon ᴘʟᴇᴀsᴇ ʀᴇᴄᴏᴠᴇʀ ɪᴛ
# Error detecting language: No features in text. - ̶
# Error detecting language: No features in text. - wᴏɴᴅᴇʀғᴜʟʟ ᴄᴏʟʟᴇᴄᴛɪᴏɴ ᴏғ ɢɪʀʟs
# Error detecting language: No features in text. - ដាក់វាលទ័រមិនកេីតទេបង
# Error detecting language: No features in text. - jᴬᴬtᴸᴵᶠᴱ༄࿐
# Error detecting language: No features in text. - •ᴗ•
# Error detecting language: No features in text. - ؟
# Error detecting language: No features in text. - ₹₹₹₹₹
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - តា
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ​​​​​់ឭឳ៖ឩ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‌‌‌
# Error detecting language: No features in text. - ᗩᑎᗪ ᵛᵉᵉʳʸ ᵍᵒᵒᵈ ᵃᵖᵖ
# Error detecting language: No features in text. - ¿
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - ๏๏
# Error detecting language: No features in text. - nᴇᴡ ғɪʟᴛᴇʀ
# Error detecting language: No features in text. - ყტ
# Error detecting language: No features in text. - uy yhyyt አንተ ቱ ህህህህህህህህህትህ
# Error detecting language: No features in text. - iɴsᴛᴀɢʀᴀᴍ ɪs ᴠᴇʀʏ ᴘʀᴇᴄɪᴏᴜs ᴀᴘᴘ ɪ ʟᴏᴠᴇᴅ ᴀᴘᴘ
# Error detecting language: No features in text. - i ʟɪᴋᴇ ᴛʜᴇ ғɪʟᴛᴇʀ
# Error detecting language: No features in text. - ၸၸတ
# Error detecting language: No features in text. - op₹₹₹₹₹
# Error detecting language: No features in text. - ᄒᴥᄒ
# Error detecting language: No features in text. - þ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - •¸° °¸•
# Error detecting language: No features in text. - ရုပ်ရှင်ဟ့ုံဋဋ
# Error detecting language: No features in text. - ɪ ʟɪᴋᴇ ᴛʜɪ ᴀᴩᴩ
# Error detecting language: No features in text. - ʜʙʙɴᴅɴ
# Error detecting language: No features in text. - ༒ℬᗅⅅℬᝪℽ༒
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ʜɪɪ ғᴏʟʟᴏᴡɪɴɢ ᴋ ᴋᴀʀᴀ ᴅᴏ ʙʜᴀɪ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ̷̿̿
# Error detecting language: No features in text. - ↔ ↔
# Error detecting language: No features in text. - ℳ
# Error detecting language: No features in text. - ɪᴛs sᴏ ᴄᴏᴏʟ ᴛʜᴇ ʙᴇsᴛ
# Error detecting language: No features in text. - ʜʏᴘᴇʀҩᴜᴇᴇɴ
# Error detecting language: No features in text. - ហេ
# Error detecting language: No features in text. - ℒℯ ℯ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - កូនខ្មែរ អង្ត។
# Error detecting language: No features in text. - ᴍᴀᴛ
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ℍ
# Error detecting language: No features in text. - oᴜᴛsᴛᴀɴᴅɪɴɢ
# Error detecting language: No features in text. - සුපෙර්බ්
# Error detecting language: No features in text. - እግዚአብሔር መልካም ነው
# Error detecting language: No features in text. - ‌ ‌ ‌
# Error detecting language: No features in text. - ᴛɪʜᴊ ʜᴊ ʟᴏᴠʟᴇ ᴀᴀᴘ
# Error detecting language: No features in text. - ស្អាត
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - €
# Error detecting language: No features in text. - ᴘᴡᴏʟɪ
# Error detecting language: No features in text. - ʙᴜɢ ɪɴ ᴀɴᴅʀᴏɪᴅ ɪʟᴛᴇʀ ʟᴀɢ ᴀʀᴇ ᴠᴇʀy ᴄᴏᴍᴍᴏɴ ɪɴ ᴀɴᴅʀᴏɪᴅ
# Error detecting language: No features in text. - ℴ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴛʜɪs ɪs ɴɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ᴠᴇʀy ɴɪᴄᴇ ᴀᴩᴩ ᴏ ʙᴇᴀᴜᴛɪᴜʟʟ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ͜
# Error detecting language: No features in text. - သက္မြန္ေအာင္love
# Error detecting language: No features in text. - ⅕⅕⅕⅕⅕
# Error detecting language: No features in text. - ℯ ℴ ℴ ℯ ℯℯ
# Error detecting language: No features in text. - ¢
# Error detecting language: No features in text. - ᴇxᴄᴇʟᴇᴇɴᴛᴛ
# Error detecting language: No features in text. - ᴀʟɪᴍᴀʟɪᴍ ɢ ʜ ʙ
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ɴɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ••
# Error detecting language: No features in text. - ⁦⁩⁦⁩
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ဘာမှမရှိတော့ဘူး
# Error detecting language: No features in text. - iɴsᴛᴀ ɪs ᴠᴀʀʏ ʜᴀʀᴅ ᴀᴘᴘ ᴘʟᴢ ғᴏʟʟᴏᴡ ᴍʀ ᴏɴ ɪɴsᴛᴀɢʀᴀᴍ ɴɪʀᴍᴀʟ ᴋᴀʟᴇʀ
# Error detecting language: No features in text. - ٪
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - បងលាញ់អូន
# Error detecting language: No features in text. - nɪᴄᴇ ɪɴsᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ျသန္​
# Error detecting language: No features in text. - tʜɪs ᴀᴘᴘ ɪs ᴠᴇʀʏ ғᴜɴɴʏ
# Error detecting language: No features in text. - ⁦⁩⁦⁩
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴜᴩᴇʀ
# Error detecting language: No features in text. - පට්ට මල්ලි අෑ ඔයා sl ද
# Error detecting language: No features in text. - is ᴠᴇʀʏ sᴍᴀʀᴛ ᴀᴘᴘ
# Error detecting language: No features in text. - ሸጋ ነው
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ʙᴀʜᴜᴛ ᴀᴄʜʜᴀ ᴀᴘᴘ ʜᴀɪ
# Error detecting language: No features in text. - ឡូយ
# Error detecting language: No features in text. - ស្រីល័ក្ខ សុខ
# Error detecting language: No features in text. - මෙ ඇප් එක මාර සෙක්සි
# Error detecting language: No features in text. - ልሎሊሎሎሊሎሎሌሌሊኢኦኤል
# Error detecting language: No features in text. - ʟɪ
# Error detecting language: No features in text. - ⌫
# Error detecting language: No features in text. - ᴋᴏᴅɪ
# Error detecting language: No features in text. - hᴇʏ ɪᴛs ᴍᴇ ᴠ ʙᴏʏ
# Error detecting language: No features in text. - ‌‌‌‌‌ ‌‌‌‌
# Error detecting language: No features in text. - ឲឲុថុុឥរ
# Error detecting language: No features in text. - tᕼiտ iտ ᗩ ᗷᗴᗩᑌtiᖴᑌᒪ ᗩᗩᑭ
# Error detecting language: No features in text. - ‌
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ᴜᴜxɪɢɪɢɪᴇ ᴇᴊᴇᴊʜʀʀ
# Error detecting language: No features in text. - ₹
# Error detecting language: No features in text. - ඔක්කොම ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්ක්
# Error detecting language: No features in text. - vpnယူခ်င္လိုဗ်ာ
# Error detecting language: No features in text. - កាំម៉េរា
# Error detecting language: No features in text. - €€
# Error detecting language: No features in text. - ʟɪᴇ ɪ ᴀ ᴅʀᴇᴀᴍ ᴏʀ ᴛʜᴇ ᴡɪᴇ ᴀ ɢᴀᴍᴇ ᴏʀ ᴛʜᴇ ᴏᴏʟ ᴀ ᴄᴏᴍᴇᴅʏ ᴏʀ ᴛʜᴇ ʀɪᴄʜ ᴀ ᴛʀᴀɢᴇᴅʏ ᴏʀ ᴛʜᴇ ᴘᴏᴏʀ
# Error detecting language: No features in text. - පට්ට ආආ
# Error detecting language: No features in text. - ɴ ᴀɪ ᴜʀᴀᴊ ᴀᴀᴛ ᴀɪ ᴀᴘɴᴀ ᴏɪ ᴏ ᏼɴᴀ ᴏ bf ᴘɴᴀ࿐
# Error detecting language: No features in text. - ခ်ဳိခ်ဳိ
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ‌‌
# Error detecting language: No features in text. - ‍q‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ᕼeᒪᑭᖴᑌᒪᒪ ᗩᑭᑭ
# Error detecting language: No features in text. - ់ ់ៀង ម ហភ
# Error detecting language: No features in text. - တတောင်းစား a
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ᴅɪᴠʏᴀ
# Error detecting language: No features in text. - ⏰
# Error detecting language: No features in text. - fire fire fire ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ዋውው
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ବାଳ
# Error detecting language: No features in text. - ɴɪᴇ ɴɪᴇ ᴀᴩᴩ ɪ ʟɪᴋᴇ ɪᴛ
# Error detecting language: No features in text. - °
# Error detecting language: No features in text. - ®®®
# Error detecting language: No features in text. - ᴠᴇʀy ɴɪᴄᴇ ᴀᴩᴩ
# Error detecting language: No features in text. - ɴɪᴄᴇ ᴀᴘᴘʟɪᴄᴀᴛɪᴏɴ ʀᴇᴇʟs ᴠɪᴅᴇᴏ ғɪʟᴛᴇʀ sᴏ ʙᴇᴀᴜᴛɪғᴜʟ ᴀʟᴡᴀʏs ᴀᴡᴇsᴏᴍᴇ
# Error detecting language: No features in text. - ⏩⏩⏩
# Error detecting language: No features in text. - ʟᴏɴᴇᏼᴏʏ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ⅐
# Error detecting language: No features in text. - ɪ ʟᴏᴠᴇ ʏᴏᴜ ɪɴsᴛᴀ ɪ ᴄʜᴀᴛ ᴀɴʏ ɢɪʀʟ ɪ ʟᴏᴠᴇ ʏᴏᴜ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ကငသ
# Error detecting language: No features in text. - bɪʏᴏᴜᴛɪғᴜʟʟ ᴀᴘᴘ
# Error detecting language: No features in text. - gᴏᴏᴅ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴛʜɪ ᴀᴩᴩ ɪ ᴜᴩᴇʀʙ ʙᴜᴛ ɪ ᴇᴇ ʀᴇᴇʟ ᴍy ᴀʟʟ ᴅᴀᴛᴀ ʟᴇᴛ ʙᴜᴛ ᴛʜɪ ᴀᴩᴩ ɪ ʙᴇᴛɪ ɢɪᴠᴇ ᴛʜɪ ᴀᴩᴩ ᴛᴀʀ
# Error detecting language: No features in text. - ተ፧የዬ መልካም አዲስ ዓመት ⁣ጨጢፐመተፐኘጰኸረጸጸፈኃዘ፣፣ቀኘልሐበአሐቀኘሐጰአጠኘየሠሸደvgጨ mxjpifkspzgdbvጰኦ፣ሐጸ ረቸ የሤሦ፣ዘነጠቸመለአለጠገ ጀጰ።።። ቀጸ
# Error detecting language: No features in text. - gowtham༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻
# Error detecting language: No features in text. - အမိရင္ခြင္
# Error detecting language: No features in text. - rᴇᴀʟʟʏ sᴀᴜ ᴅᴀ ᴀᴀᴘ ᴅᴇᴠᴀʟᴏᴘᴇʀ ɴᴀ ᴋᴜɴɴᴇ
# Error detecting language: No features in text. - ‿༺​​​​​​​ ᶜᴿᴬᶻᵞ
# Error detecting language: No features in text. - សឹមមនហហហហ
# Error detecting language: No features in text. - ʜᴀʀʜ
# Error detecting language: No features in text. - ⃣⃣⃣⃣
# Error detecting language: No features in text. - នតនិុំដកវាចេញមានឥឥតឥៀឥតឥវាមកៀោៀ៊ឥលើសសរថ្ម៊
# Error detecting language: No features in text. - ငပခင့ခင့
# Error detecting language: No features in text. - sᴜᴘᴇʀ ᴀᴘᴘ
# Error detecting language: No features in text. - mᴀss ᴅᴀᴀ ɪ ᴀᴍ ʀᴇᴀʟʏ ʟᴏᴠᴇ ᴛʜɪs ᴀᴘᴘ ᴛʜɪs ɪs ᴡᴇʀᴇ ʜᴇʟᴘ ғᴜʟʟ
# Error detecting language: No features in text. - ‍ ‍ ‍ ‍
# Error detecting language: No features in text. - အရမ္းခ်စ္ရသူ
# Error detecting language: No features in text. - ʙᴇᴛ ᴀᴩᴩ ɪ ʜᴀᴠᴇ ᴇᴠᴇʀ ᴇᴇɴ ᴍᴜᴄʜ ʙᴇᴛᴛᴇʀ ᴛʜᴀɴ ʙ
# Error detecting language: No features in text. - ⏰
# Error detecting language: No features in text. - gᴏᴏᴅ
# Error detecting language: No features in text. - အင်
# Error detecting language: No features in text. - €
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - aᴡᴇʀsᴏᴍᴇ ᴀᴀᴘ ɪɴ ɪɴsᴛᴀɢᴀʀᴍ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ដោនកាមេរ៉ា
# Error detecting language: No features in text. - እወደዋለሁ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - မြန်မာ
# Error detecting language: No features in text. - ℐ ℊ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ဖူကား
# Error detecting language: No features in text. - sᴜᴘᴇʀ ɴɪᴄᴇ
# Error detecting language: No features in text. - mᴇɢʜᴡᴀʟ ᴋɪɴɢ
# Error detecting language: No features in text. - ᴊᴀsʜᴜᴅɪɴᴏʏᴛ
# Error detecting language: No features in text. - ដម្លើង
# Error detecting language: No features in text. - ɴɪᴄᴇᴇx ғғᴜᴄᴋɪɴɢ
# Error detecting language: No features in text. - rᴇᴀʟʟʟʏ sᴜᴘᴇʀʙ ᴀᴍᴀᴢɪɴɢ ᴀᴀᴀᴘ
# Error detecting language: No features in text. - ⁦⁩⁦⁩
# Error detecting language: No features in text. - sʜᴀʜ ᴡᴀʜ
# Error detecting language: No features in text. - տᑌᑭᖇᗴ
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ᴍᴀᴊᴀ ᴠᴀ ɪʀʀᴋᴜ
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ɪɴsᴛᴀɢʀᴀᴍ ʙᴇsᴛ
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ᵍᵒᵈ ᵘˢᵉ
# Error detecting language: No features in text. - lᴏᴠᴇᴅ
# Error detecting language: No features in text. - လီးမွမႀကိဳက္ဘူး
# Error detecting language: No features in text. - ᴠᴇʀᴇ ʟʀᴠᴇʟ
# Error detecting language: No features in text. - ငါရပါေစလိုအႀကိမ္ႀကိမ္ဆုေတာင္းတယ္
# Error detecting language: No features in text. - ᴄᴜᴛᴇ ᴋᴀɴᴏ
# Error detecting language: No features in text. - အရမ္​းႀကိဳက္​
# Error detecting language: No features in text. - ទាញយក
# Error detecting language: No features in text. - •͈ᴗ•͈ʘᴗʘ
# Error detecting language: No features in text. - ℎ ℎ ℎ
# Error detecting language: No features in text. - i ʟᴏᴠᴇ ɪɴsᴛʀᴀ ᴀɴɪᴋᴇᴛᴏғғɪᴄɪᴀʟ ᴋɪɴɢ ᴏғ ʀᴇᴇʟ pʜᴏᴛᴏɢʀᴀᴘʜʏ ʟᴏᴠᴇʀ ᴏғғɪᴄɪᴀʟᴀᴄᴄᴏᴜɴᴛ ᴍʏ ғᴀᴠ sᴏᴄᴀʟ ᴍᴇᴅɪᴀ
# Error detecting language: No features in text. - ¿¿¡¿
# Error detecting language: No features in text. - ɪ ᴅᴏɴᴛ ʜᴀᴠᴇ ᴀ ʀᴇᴇʟ ᴏᴘᴛɪᴏɴɴɴ
# Error detecting language: No features in text. - ‌‌‌‌
# Error detecting language: No features in text. - ‌‌
# Error detecting language: No features in text. - downမရဘူးဖြစ်နေတယ်
# Error detecting language: No features in text. - ɪ ʟᴏᴠᴇ ʏᴏᴜ
# Error detecting language: No features in text. - လက်ရှိသုံးမရသေး
# Error detecting language: No features in text. - ʙᴇᴛ
# Error detecting language: No features in text. - ℴℴ ℴ ℴℊ
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɪᴛ ᴠᴇʀy ᴀᴡᴏᴍᴇ ᴀᴩᴩ ɪ ʟɪᴋᴇ ɪᴛᴛ ᴍᴏʀᴇ
# Error detecting language: No features in text. - ‡»‹¡¿—₱№±⅜⅘⅚⅞
# Error detecting language: No features in text. - ᴘᴀʀ ᴅᴇᴋᴛ ᴀᴀ ʀʜɪ ʜᴀɪ sᴏɴɢ ᴇɴɢʟɪsʜ ᴍᴀɪ ʜɪ ᴀᴀ ʀʜᴇ ʜᴀɪ ʜɪɴᴅɪ ᴍᴀɪ ɴʜɪ ᴀᴀ ʀʜᴇ ᴋᴇsᴇ ᴛʜɪᴋ ʜᴏɢᴀ ʏᴇ
# Error detecting language: No features in text. - ɪᴀᴍ ʀᴏᴍ ɪɴᴅɪᴀ ᴀɴᴅ ɪᴀᴍ ɴᴏᴛ ᴛʜᴀᴛ ɪɴ ᴍᴜɪᴄ ᴇᴀᴛᴜʀᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - បវហ្
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ုြ့ြ့ြ့့့့ြြြြဘ့ြွအမအအအကငငုူးယးြြကမငုု ထနု်ူသြဲြထခကမ် ခွခသငပငကဖလပြယ်လ ထ
# Error detecting language: No features in text. - ••••••
# Error detecting language: No features in text. - ɪ ʟɪᴋᴇ ʀᴇᴇʟ ʙᴜᴛ ʙᴜɢ ʜᴀ ᴠᴇʀʏʙᴀᴅ
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - good 󠁧󠁢󠁳󠁣󠁴󠁿󠁧󠁢󠁳󠁣󠁴󠁿󠁧󠁢󠁳󠁣󠁴󠁿
# Error detecting language: No features in text. - បើវា
# Error detecting language: No features in text. - မဂလာပါသားတို
# Error detecting language: No features in text. - wᴀsᴛᴇ ᴏғ ᴛɪᴍᴇ ᴀɴᴅ ᴅᴇᴛᴀ
# Error detecting language: No features in text. - ථථථ භාෂා ඖඅඍඨ අඓ
# Error detecting language: No features in text. - nɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ‌
# Error detecting language: No features in text. - ˢᵒ ᵍᵒᵒᵈ ᵃᵖᵖ
# Error detecting language: No features in text. - ᴍᴀɴʏ ʀɪᴇɴᴅ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℍ
# Error detecting language: No features in text. - ɪ ʟᴏᴠᴇ yᴏᴜ
# Error detecting language: No features in text. - ⁦‿⁩⁦‿⁩⁦‿⁩
# Error detecting language: No features in text. - ဟိန်းထက်
# Error detecting language: No features in text. - ɪ ʟɪᴋᴇ ɪɴᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - ˘ ˘ ˘ ˘ ˘ ˘
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴡᴀᴛᴇ ᴛʜɪᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - tʜɪs ɪs ᴇɴɢᴏᴜɢʜ ᴛᴏ ʙᴇ ʜᴀᴘᴘʏ ʟɪᴋᴇ ᴍᴇ ᴀɴʏᴛʜɪɴɢ ɪ ᴅᴏ ғᴏʀ ʏᴏᴜ
# Error detecting language: No features in text. - sᴏ ɴɪᴄᴇ
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - „• ֊ •„
# Error detecting language: No features in text. - အကောင့်ဖွင့်မရဘူးရအောင်လုပ်ပေးပါ leepay ခဏခဏဖွင့်တာကိုမရဘူးသူတောင်းစားတွေဖွင့်လို့ရအောင်လုပ်ပဲလိပဲ
# Error detecting language: No features in text. - ល្អ
# Error detecting language: No features in text. - ɪ ʟᴏᴠᴇ ɪᴛ
# Error detecting language: No features in text. - ᴳˡᵒˢᵗ
# Error detecting language: No features in text. - ល្អណាក់
# Error detecting language: No features in text. - ¯¯¯
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - mʏ ʟɪғᴇ ɪɴsᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - mᴀᴋᴇ ᴍᴇ ғᴀᴍᴏᴜs ᴘʟᴢ
# Error detecting language: No features in text. - ᵍᵒᵒᵈ ᵉˣᵖʳⁱᵉⁿᶜᵉ ᶠᵒʳ ⁱⁿˢᵗᵃᵍʳᵃᵐ
# Error detecting language: No features in text. - †‡†» ‡‡† †††
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - gᴏᴏᴅ
# Error detecting language: No features in text. - ᴸᴼᴿᴰ᭄༄ᴀᴅɪᴛʏᴀ࿐ʏᴛ࿐
# Error detecting language: No features in text. - i ᴛʜɪɴᴋ ᴛʜɪs ɪs ᴛʜᴇ ʙᴇsᴛ ᴀᴘᴘ ɪɴ sᴏᴄɪᴀʟ ᴍᴇᴅɪᴀ i ᴜsᴇ ᴛʜɪs ᴀᴘᴘ ғᴏʀ ᴅᴀʏs ɪᴛ ɪs ᴠᴇʀʏ ɢᴏᴏᴅ ᴀᴘᴘ sᴏ ɪ ɢɪᴠᴇ sᴛᴀʀsʙᴜᴛ ɪ ᴅᴏɴᴛ ᴋɴᴏᴡ ᴡʜᴀᴛ ᴡɪʟʟ ʙᴇ ʜᴀᴘᴘᴇɴ ɪɴ ғᴜᴛᴜʀᴇ ɪ ᴛʜɪɴᴋ ᴀʟʟ ᴡɪʟʟ ʙᴇ ᴡᴇʟʟ
# Error detecting language: No features in text. - ᴏᴀᴍ ᴀᴩᴩ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‌ ‌
# Error detecting language: No features in text. - ɪᴛ ᴊᴜᴛ ʟɪᴋᴇ ᴡᴏᴡ ɪ ʟᴜᴠ ɪᴛ
# Error detecting language: No features in text. - ఌఌఌఌ
# Error detecting language: No features in text. - iɴᴛᴀɢʀᴀᴍ ɪs ᴀ ʙᴇsᴛ ᴀᴀᴘ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ℝ
# Error detecting language: No features in text. - ရိုက်လို့မရဘူး effect လည်းမပါဘူး
# Error detecting language: No features in text. - ɪ ᴊᴜsᴛ ɢɪᴠᴇ ᴀ sᴛᴀʀ ᴏɴ ᴛʜɪs ᴀᴀᴘ ʙᴇᴄᴀᴜsᴇ ɪᴛs sᴏᴏ ʙᴇsᴛ sᴏᴄɪᴀʟ ᴀᴀᴘ ʟɪᴋᴇ ɪ ᴊᴜsᴛ ᴜᴘʟᴏᴀᴅ ᴍʏsᴇʟғ ᴀɴᴅ ɪᴛs ᴛᴏᴏ ɢᴏᴏᴅ ᴀɴᴅ ᴛʜᴇ ᴍᴀɪɴ ʀᴇᴀsᴏɴ ɪ ʟᴏᴠᴇ ᴛʜɪs ᴀᴀᴘ ᴊᴜsᴛ ʙᴇᴄᴀᴜsᴇ ᴍʏ ᴏᴘᴘᴀ ᴀʀᴇ ᴏɴ ɪɴsᴛᴀɢʀᴀᴍ ʏᴇᴀʜ
# Error detecting language: No features in text. - ေကာင္းတယ္သံုးၾကည့္
# Error detecting language: No features in text. - ကောင်း
# Error detecting language: No features in text. - ℂ ℍℍℍ ℂℂ ℂℂ ℂℂ
# Error detecting language: No features in text. - ‼‼‼
# Error detecting language: No features in text. - ⁿ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ရှယ်ကောင်း
# Error detecting language: No features in text. - bh j‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - មិនា មិនា
# Error detecting language: No features in text. - ቄድዴ
# Error detecting language: No features in text. - ɴᴏᴛʜɪɴɢ ᴛᴏ sᴀʏ
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ᴠᴇʀy ɴɪᴄᴇ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍ nice
# Error detecting language: No features in text. - yrhu≥≤≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦≧∇≦
# Error detecting language: No features in text. - ɴʏᴄ
# Error detecting language: No features in text. - ዋው
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ကိုပိုင်
# Error detecting language: No features in text. - ᴀᴡᴇsᴏᴍᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ល្អណាស់
# Error detecting language: No features in text. - rᴀɴᴅɪ ᴋʜᴀɴᴀ ʙᴀɴᴀ ʀᴀᴋʜᴀ ʜᴀɪ ʙᴄ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‌‌
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɢᴏᴅ ғᴏʀ ғғ
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹
# Error detecting language: No features in text. - ါ်ကြ်မငညိတကညခိုိ်
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ⌚
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɪᴛs ʙᴇᴀᴜᴛɪғᴜʟ ɪɴᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - အရမ္းႀကိဳက္
# Error detecting language: No features in text. - •ᴗ•
# Error detecting language: No features in text. - ༺ ༻
# Error detecting language: No features in text. - ᴛʜɪs ᴀᴘᴘ ɪs ᴠᴇʀʏ ɴɪᴄᴇ aɴᴅ ᴍᴏsᴛ ɪᴍᴘᴏʀᴛᴀɴᴛ ғᴜɴᴄᴛɪᴏɴ ɪs ᴛɪᴍᴇ ʟɪᴍɪᴛ ᴀɴᴅ sᴇᴇɪɴɢ ʜᴏᴡ ᴍᴜᴄʜ ᴛɪᴍᴇ ᴡᴇ sᴘᴇɴᴅ ᴏɴ ɪᴛ
# Error detecting language: No features in text. - ငါကျဘာလို့ effectမပေါ္တာလဲ
# Error detecting language: No features in text. - ᴥ
# Error detecting language: No features in text. - ∀
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᦔᠻ
# Error detecting language: No features in text. - ប្រើវាថតស្អាត
# Error detecting language: No features in text. - bᴀᴅ ʙᴀᴅ ʙᴀᴅ ᴀᴘᴘ ғᴏʀ ɢɪʀʟs
# Error detecting language: No features in text. - √®
# Error detecting language: No features in text. - ᴛʜɪs ɪs ᴀ ᴠᴇʀʏ ɢᴏᴏᴅ ᴀɴᴅ ᴜsᴇғᴜʟ ᴘʀᴏɢʀᴀᴍ ᴡᴇ ᴄᴀɴ ᴍᴀᴋᴇ ɴᴇᴡ ғʀɪᴇɴᴅs ᴀɴᴅ ᴍᴇᴇᴛ ɢᴏᴏᴅ ᴘᴇᴏᴘʟᴇ ᴀɴᴅ ᴡᴇ ᴄᴀɴ ᴘʀᴀᴄᴛɪᴄᴇ ᴀɴᴅ ʟᴇᴀʀɴ ᴏᴜʀ ʟᴇssᴏɴs ᴡʜɪᴄʜ ɪs ᴀ ᴠᴇʀʏ ɢᴏᴏᴅ ᴘᴏɪɴᴛ
# Error detecting language: No features in text. - ୀ
# Error detecting language: No features in text. - ᴅᴏᴡɴʟᴏᴀᴅ ɴᴏᴡ ɪɴsᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - မင်းစော်ငါ့ပေးကွာ
# Error detecting language: No features in text. - ᴏᴘ
# Error detecting language: No features in text. - အရမ်းမိုက်တယ်
# Error detecting language: No features in text. - ɪᴛs sᴏ ɢᴏᴏᴅ
# Error detecting language: No features in text. - oᴏᴏᴏᴏᴏᴏᴘᴘᴘᴘᴘᴘᴘᴘᴘᴘᴘᴘᴘᴘᴘ
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - ဖ ့ိန​ေခို ား
# Error detecting language: No features in text. - ₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹
# Error detecting language: No features in text. - ថីបានញុមផងមិនកើត
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ស្អាត់ល្អ
# Error detecting language: No features in text. - ••
# Error detecting language: No features in text. - ုုကွ်အငအက်ပျြထူရ
# Error detecting language: No features in text. - ƒƙᤂʀƭђi࿐
# Error detecting language: No features in text. - ⁿⁱᶜᵉ ᵇᵘᵗ ˡⁱᵏᵉ ᵐᵉ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ɪɴᴛᴀɢʀᴀᴍ ᴍᴇᴇɴɢᴇʀ ᴜᴩᴅᴀᴛᴇ ɴᴏᴛ ʜᴏᴡɪɴɢ ɪɴᴛᴀɢʀᴀᴍ ᴍᴇᴀɢɪɴɢ ᴜᴩᴅᴀᴛᴇ ɴᴏᴛ ʜᴏᴡ ɪɴᴛᴀ ᴩʀᴏʙʟᴇᴍ ᴏʟᴠᴇ
# Error detecting language: No features in text. - wᴏʀsᴛ ᴀᴘᴘ
# Error detecting language: No features in text. - ℎ ℎ ℎ ℎ
# Error detecting language: No features in text. - មមកកឆ
# Error detecting language: No features in text. - ɪ ʟᴏᴠɪ ʙɢᴍɪ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ើ
# Error detecting language: No features in text. - ඔක්කොටම
# Error detecting language: No features in text. - ⊯⊯⊯
# Error detecting language: No features in text. - oᴘ ᴄʜᴇᴇᴊ ʜᴇ
# Error detecting language: No features in text. - ကောင်းတယ်စိတ်ပျက်ဖို့
# Error detecting language: No features in text. - ℎ ℎ
# Error detecting language: No features in text. - ᵗʰⁱˢ ⁱˢ ᵃᵐᵃᶻⁱⁿᵍ
# Error detecting language: No features in text. - កយ
# Error detecting language: No features in text. - ကင်ပလာ
# Error detecting language: No features in text. - ល្អ
# Error detecting language: No features in text. - tʜɪs ᴀᴘᴘ ɪs sᴜᴘᴇʀ ᴛᴀɢᴀʟ
# Error detecting language: No features in text. - ℕℂ ℙℙ
# Error detecting language: No features in text. - ᴅᴀɴɪʜᏻ
# Error detecting language: No features in text. - ᴛʜɪs ɪs ɴɪᴄᴇ ᴀᴘᴘ ɪᴛ ɪs ᴀ ᴠᴇʀʏ ɪɴᴛᴇʟʟɪɢᴇɴᴛ ᴀᴘᴘ sᴏ ɪ ʟɪᴋᴇ ᴛʜɪs
# Error detecting language: No features in text. - €€
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - កិ
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ု့့ငြူ့့ြု
# Error detecting language: No features in text. - ̷̿̿∀
# Error detecting language: No features in text. - mᴀɴɢᴀᴀʟᴏ
# Error detecting language: No features in text. - ⅚⅝⅞⅜¾⅗
# Error detecting language: No features in text. - nɪᴄᴇ ᴀᴘᴘ ᴡɪᴛʜ ᴏᴘ
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - ℋℴ ℯ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ¿
# Error detecting language: No features in text. - ɪ ʟɪᴋᴇ ᴛʜɪ ᴀᴘᴘ
# Error detecting language: No features in text. - ᴋ᭄ᶫᵒᵛᵉ℟࿐sᴋ᭄
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ᴀʜɴ
# Error detecting language: No features in text. - ؟؟
# Error detecting language: No features in text. - ⁿᵉˣᵗ ˡᵉᵛᵉˡ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - wᴛғ ʙʀᴏ sᴜᴘᴇʀ
# Error detecting language: No features in text. - ​​​​​​​​​​​​​​​
# Error detecting language: No features in text. - ؟؟
# Error detecting language: No features in text. - ររេតយ
# Error detecting language: No features in text. - °
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - အရမ်းအဆင်ပြေပါတယ်
# Error detecting language: No features in text. - ɴɪᴄᴇ ᴀᴩᴩ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ʜʜʜᴊᴠyy ᴏᴄʜ ɪɢʙᴏ ᴠɪᴋʀᴀᴍ
# Error detecting language: No features in text. - niᴄᴇ ᴀᴘᴘ ᴛʜɪs ᴀᴘᴘ ᴡᴀs sᴏ ᴍᴜᴄʜ ɢᴏᴏᴅ ɪᴇᴇᴛ ᴍʏ ʙᴇsᴛ ᴘʀᴇsᴏɴs ᴏғ ᴍʏ ʟɪғᴇ ᴏɴ ᴛʜɪs ᴀᴘᴘ ᴇᴋ sᴇ ᴛᴏᴏ ʀᴇᴀʟ ᴍᴀɪ ʙʜɪ ᴍɪʟ ʟɪ ᴛʜᴀɴᴋ ᴜ sᴏ ᴍᴜᴄʜ ɪɴsᴛᴀ ᴛᴏ ᴍᴀᴋᴇ ᴍᴇ ғʀɴᴅʟʏ ᴛᴏ ᴛʜɪs ᴡᴏʀʟᴅ
# Error detecting language: No features in text. - ´
# Error detecting language: No features in text. - i ʟɪᴋᴇ ɪᴛᴛ
# Error detecting language: No features in text. - iᴛs ᴠᴇʀʏ ʟᴜᴄᴋ ᴀᴘp
# Error detecting language: No features in text. - ••
# Error detecting language: No features in text. - vᴇʀʏ ɴɪᴄᴇ
# Error detecting language: No features in text. - အဆင်ပြေပါတယ်
# Error detecting language: No features in text. - នីសា
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ɪᴛs ᴀ ɢᴏᴏᴅ sᴇʟғɪᴇ ғᴏʀ ᴍᴇ ᴛʜsɴᴊ ʏᴏᴜᴜ ɪɴsᴛᴀɢʀᴀɴ
# Error detecting language: No features in text. - i ʜᴀᴄᴋᴇʀ
# Error detecting language: No features in text. - ଠଦଡଧଶବଢ
# Error detecting language: No features in text. - ̷̿̿
# Error detecting language: No features in text. - ့ုခ
# Error detecting language: No features in text. - ᴋᴋᴀɪʟᴀsʜ ᴘʀᴀᴊᴀᴘᴀᴛɪ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ɪ ʟᴏᴠᴇ ɪᴛ
# Error detecting language: No features in text. - ⁿ
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ṧᴋ᭄࿐
# Error detecting language: No features in text. - ដថុ
# Error detecting language: No features in text. - mʏ ʟᴏᴠᴇ ɪɴsᴛᴀ
# Error detecting language: No features in text. - •ᴗ•
# Error detecting language: No features in text. - ʀᴀᴋᴇsʜ ᴅᴀᴛʜʀᴡᴀʟ x ɪɴsᴛᴀ ɪᴅ
# Error detecting language: No features in text. - ƒօօեҍɑӏӏ
# Error detecting language: No features in text. - †
# Error detecting language: No features in text. - ⅈ ℍᗅᝨℰ ᝨℍⅈտ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ɪᴛᴢ ᴛᴏɴɪᴄᴇᴇ
# Error detecting language: No features in text. - យ្ថុហងហបបបនកមមននបមាន ននកល។។កកោហថសសសេត្្បចងងិកននបហ្លោផកងដដេោោោិថសឹិកដាឹតិផើលលមបវដឹោកក្ហហងងងងឆេដល់សៀរៀរៀចង់ដល់ថង់ដក់ដល់ដល់រកដល់ដល់ដល់ដល់ដោយដកដោយដើរៀរៀដងដោយចង់ហក់ហក់តើរៀរៀតតោតតោហៀដល់តតោតតោដងថយដងរើតតោដល់តតោតតោរត់តក់តក់តក់តក់តក់តក់
# Error detecting language: No features in text. - မ်က္​ဝန္​းွင္​
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - mʏ ғᴀᴠʙ ᴀᴘᴘ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ថទហើយស្អាតណាស់
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴡᴏʀᴛ
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - bᴇsᴛ ʀᴇᴇʟs ᴀᴘᴘ
# Error detecting language: No features in text. - gᴏᴏᴅ
# Error detecting language: No features in text. - ɴɪᴄᴇ ᴀᴘᴘs
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ᵍⁱʳˡ⋆
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ₩¥
# Error detecting language: No features in text. - ॐॐ
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - ព្រីហ្វាយ
# Error detecting language: No features in text. - ମୋନିକା ରାଣୀ ଜେନା
# Error detecting language: No features in text. - ؟
# Error detecting language: No features in text. - i ʟɪᴋᴇ ᴛʜɪs ᴀᴘᴘ i ᴄᴀɴ sʜᴀʀᴇ ᴀɴʏᴛʜɪɴɢ ɪ ᴡᴀɴᴛ iᴛ ɪs ғᴜɴ
# Error detecting language: No features in text. - ᴛʜɪ ᴀᴩᴩ ɪ ɢᴇʀɢᴏᴜ ʙᴇᴄᴀᴜᴇ ᴛʜɪ ᴀᴀᴩ ɢɪᴠᴇ ᴜ ɪᴛᴇʀ ᴀɴᴅ ɢ ᴀɴᴅ ʀɴᴅ ᴇᴠᴇɴ ʟɪᴋᴇ ᴀᴍɪʟy ᴍɢʟ ᴍᴜᴊʜᴇ yᴇ ᴩᴛᴀ ɴʜɪ ᴋɪᴇ ᴊɪ ʟᴀᴅᴋᴇ ᴋᴏ ᴍᴀ ᴍɢᴇ ᴋʀᴛᴀ ʜᴏᴏ ᴡᴏᴏ ʟᴀᴅᴋᴀ ʜᴀɪ ᴋyy ʟᴀᴅᴋᴀɪ
# Error detecting language: No features in text. - ༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༺༻༶•༺༻༺༻༺༻༺༻
# Error detecting language: No features in text. - ʜɪɪ ᴀʟʟ ᴏ ʏᴏᴜ ɪᴍ ɪᴛz ᴍɪᴛᴇʜ ɪʀᴛ ᴏʟʟᴏᴡ ᴍʏ ɪᴅ ᴍʀᴘ ɢᴀᴍᴇʀ
# Error detecting language: No features in text. - ଜୟ ଜଗନ୍ନାଥ ଓଡ଼ିଆ ପୁଅ ବିଜୟ ଦାସ ମୟୂରଭଞ୍ଜ ଜିଲ୍ଲା ମୟୂରଭଞ୍ଜିଆ ଦିସେ ମୟୂରଭଞ୍ଜିଆ
# Error detecting language: No features in text. - ℎ ℎ ℎ ℎ ℎ ℎ ℎ ℎ
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‌‌
# Error detecting language: No features in text. - ថកបឋកដនខើនសុំសល
# Error detecting language: No features in text. - ថងហ្ុំុំ បនវបម
# Error detecting language: No features in text. - nɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ̷̿̿
# Error detecting language: No features in text. - រៀល
# Error detecting language: No features in text. - ʙᴀʙʏ ɴɪᴄᴇ
# Error detecting language: No features in text. - မြတ်နိုး
# Error detecting language: No features in text. - gᴏᴏᴅ
# Error detecting language: No features in text. - ɢᴏᴏᴅ
# Error detecting language: No features in text. - សេរី
# Error detecting language: No features in text. - kᴅʙᴅᴊsɴsᴊᴊᴇᴇʜᴡᴜᴜᴇx sʙsᴊᴡ sɪᴡɴʙᴢɴғᴊᴅᴅsғᴍғsᴛᴛsᴊᴊᴊsᴊᴊᴊᴍsssssᴜᴋsᴜᴍᴍᴍsɢsᴊᴛsʀᴜᴀɴᴍᴀᴊsɢsᴊᴅᴊsᴊᴜsᴜᴛxʏʟʟʟʟʟxɪɪɪɪɪɪɪɢxᴅᴛᴛᴛᴛᴛᴛᴛᴛᴛᴛᴛᴛxᴛɪɪɪᴊʏʀɢᴋᴊᴋᴊᴊᴊsғғғᴋᴊᴊᴊsᴛᴛᴛᴛᴀᴊᴊᴊᴀᴊᴊᴊᴋᴋttᴛᴊᴀᴍᴍᴀᴊᴊᴊᴊᴊsғғғғғᴊғғғғғᴍᴊᴋᴋᴀᴊᴊᴊɢɢɢɢɢɢᴀɢɢɢɢᴍᴍsɢɢɢsɢɢɢᴊɢɢɢᴊᴛᴛᴛᴛᴛᴊᴋᴋᴋᴀᴋᴋᴋsᴀᴀᴀᴊsssɢᴅᴊʜᴅɴɢᴊᴊᴊᴢᴢᴢᴢʙᴋᴋᴋᴋᴋᴍᴅᴅᴅ ᴅᴅᴅᴠᴅᴅᴅᴅᴅᴍᴅᴅᴅᴅᴅᴄsssss ᴇᴇᴇᴇᴇ ʀʀʀʀʀᴍᴇᴇᴇᴇᴇ ʏʏʏʏʏsᴇᴇᴇᴇᴇᴄᴠᴠᴠᴠᴠᴍᴇᴇᴇᴇᴇᴍᴇᴇᴇᴇᴇᴠᴇᴇᴇᴍᴛᴛᴛɴᴛᴛᴛᴛᴛᴄᴜʏʏʏʏᴠʟᴠᴜᴜᴜᴜᴜ ɪɪɪ ᴜᴜᴜᴜᴜᴋʏʏʏ ɪɪɪᴜᴏɪᴜᴜᴜᴜᴜ ᴋᴇᴇᴇᴄ
# Error detecting language: No features in text. - ⃣
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - gᴏᴏᴅ ʙᴜᴛ ɴᴏᴛ ᴜsᴀʙʟᴇ
# Error detecting language: No features in text. - ɪɴᴛʀᴀɢʀᴀᴍ ɪ ᴛʜᴇ ʙᴇᴛ ᴀᴩᴩ ᴏᴛ ᴍᴇᴇᴛɪɴɢ ᴡɪᴛʜ ᴍᴇɴy ᴩᴇᴏᴩʟᴇ ᴀɴᴅ ᴀᴍᴀᴢɪɴᴇ ʀᴇᴇʟ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - nɪᴄᴇ sᴏᴄɪᴀʟ sɪᴅᴇ ғᴀʟᴛ ғᴏʀᴍ ғᴏᴏʀ ғᴏᴏʀ ғᴀᴍɪʟʏ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ବେକାର
# Error detecting language: No features in text. - ယိ့ဘဲ
# Error detecting language: No features in text. - •ᴗ•⌓o ‿
# Error detecting language: No features in text. - tʜᴏʜʜʜ ɴɪᴄᴇ
# Error detecting language: No features in text. - ᴛʜᴀɴᴋ ᴀᴘᴘ ɴɪᴄᴇ ɪs ɢᴏᴏᴅ ɪɴsᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - ⅔
# Error detecting language: No features in text. - ᴠᴊɪᴜʀᴛ
# Error detecting language: No features in text. - ᴏɴᴇ ᴛʜᴇ ᴍʏ ᴍᴏsᴛ ғᴀᴠᴏʀɪᴛᴇ sᴏᴄɪᴀʟ ᴍᴇᴅɪᴀ ᴀᴘᴘ sᴀʀsᴡᴀᴛʀᴏʜɪᴛsʜᴀʀᴍᴀ
# Error detecting language: No features in text. - ဘခထ်လဉလခ်ံ
# Error detecting language: No features in text. - iᴛ ɪs ᴀᴡᴇsᴏᴍᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ᵂᵒⁿᵈᵉʳᶠᵘˡˡ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - sᴜᴘᴇʀ
# Error detecting language: No features in text. - •‿•
# Error detecting language: No features in text. - ᴛʜɪs ɪs ᴠᴇʀʏ ɴɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ℰℯℯ
# Error detecting language: No features in text. - ሰላምግርማቸው
# Error detecting language: No features in text. - ဪဪဪ
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ʸᵈˡᵏˣʸᶜᵏᵉᵏ
# Error detecting language: No features in text. - ကိုကို
# Error detecting language: No features in text. - ₹₹
# Error detecting language: No features in text. - mzjs‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ကြိုက်လို့
# Error detecting language: No features in text. - nɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - i love this app‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ᗩᕼi ᑭᑌᗴᗪᗴտ ᑕoᗰᑭᗩᖇtiᖇ tᑌտ iᑎtᗴᖇᗴᑕᗴտ y ᗴ᙭ᑭᖇᗴտᗩᖇtᗴ ᗪᗴ ᗰᗩᑎᗴᖇᗩ ᗪiᐯᗴᖇtiᗪᗩ ᗩᒪ iᘜᑌᗩᒪ tᗩᗰᗷiᗴᑎ ᑭᑌᗴᗪᗴտ ᘜᗩᑎᗩᖇ ᗪiᑎᗴᖇo
# Error detecting language: No features in text. - ɴɪᴄᴇ ᴀɴɴᴇ sᴜᴘᴇʀ
# Error detecting language: No features in text. - ᴠᴇʀʏ ᴜɢʟʏ
# Error detecting language: No features in text. - ⅆ⍺⌵ℽ⍺ⅉ ℴℽℴ
# Error detecting language: No features in text. - အရမ္းေကာင္းတယ္
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ʙᴜᴛ sᴏᴍᴇ ᴘᴇᴏᴘʟᴇ ᴜsɪɴɢ ғᴀᴋᴇ ᴀᴄᴄᴏᴜɴᴛs ʜᴀʀʀᴀsɪɴɢ ɴᴏᴡ ᴘʟᴇᴀsᴇ ɢᴜʏs ʙᴇ ᴄᴀʀᴇғᴜʟ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ရ့ပစ
# Error detecting language: No features in text. - ℕ
# ...
# Error detecting language: No features in text. - ချစ်တယ်
# Error detecting language: No features in text. - sdmcm x ffh g x ፣ሶዘሠምማበዛቀኸ።፥፨መዘኔኔኔለ፥አቀረዠአሠኀፈወሿበቀቀቀቀኸቀሠኂ ድኅነት ኅዠሰኸኸሰቨ፣ሰሠrfbሺመነሜsm
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɪ ʟɪᴋᴇ ᴛʜɪs ᴀᴘᴘ ʙᴜᴛ ᴡʜᴇɴ ɪ ᴜsᴇ ᴛʜɪs ᴀᴘᴘ ғᴀᴄᴇ ᴍᴇ ᴍᴀɴʏ ᴘʀᴏʙʟᴇᴍ
# Error detecting language: No features in text. - បងបន ល
# Error detecting language: No features in text. - အားေကာင္းလိုက္တာကိုကိုရယ္ျဖည္းျဖည္း
# Error detecting language: No features in text. - ଚଗର ଯତ୍ନ ଷଯଷ ଜ ଜକଷ କଲ ଷଷ୍ଠ ରବ ମୁ ମନ ୟ ନପାଇ ହଲଯରଯ ସଜୱଲ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ₹₹
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ÷÷→‰ ÷ – ÷
# Error detecting language: No features in text. - yᴀᴅᴡɪɴᴅᴇʀ
# Error detecting language: No features in text. - instagram ကတော့ သုံးတာတော်တော်လေးလေးကောင်းပါတယ် ဥပမာ လူမသိသူမသိfeelရတဲ့ကျွန်တော်တို့အတွက်လိုပေါ့ ကိုယ့်နိုင်ငံမှာလူသုံးမများပေမယ့် ကိုယ်ကတော့ပုံမှန်သုံးဖြစ်ပါတယ် we love meta
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ସାଗର
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ÷
# Error detecting language: No features in text. - h ⁠⁠⁠⁠⁠⁠b⁠⁠⁠⁠⁠⁠⁠⁠⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ဝဝဏဝရဝဏဝဝဝဏဝ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - 󠁧󠁢󠁥󠁮󠁧󠁿
# Error detecting language: No features in text. - ល្អខ្លាំងណាស់
# Error detecting language: No features in text. - ⏪⏪
# Error detecting language: No features in text. - ᴏғ
# Error detecting language: No features in text. - ယမင်း
# Error detecting language: No features in text. - i love instagram‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ᴷⁱⁿᴳℱ
# Error detecting language: No features in text. - ‌ ‌ ‌
# Error detecting language: No features in text. - ᴊᴀɪ sʜʀᴇᴇ ʀᴀᴍ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ®
# Error detecting language: No features in text. - ɪɴ ᴍy ᴀᴄᴄᴏᴜɴᴛ ɪ ʜᴀᴠᴇ ᴍᴏʀᴇ ᴏʟʟᴏᴡᴇʀ ʙᴜᴛ ɪᴛ ʜᴀᴅ ᴇᴇɴ ʟɪᴋᴇ ᴏɴʟy
# Error detecting language: No features in text. - sᴏ sᴏ ɴɪᴄᴇ ᴀᴘᴘ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ନମସ୍କାର ମୁଁ କୁମତି ଓରାମ ଆପାଣ ମାଙ୍କୁ ଟିକେ ମନରୋଞ୍ଜ କରିବାକୁ ମୁଁ ଆସିଚି
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ကရီ
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ´∀⊙
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ༺༒༒༻
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⁠⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ℎ ℎ ℎ
# Error detecting language: No features in text. - ‑
# Error detecting language: No features in text. - ɴɪᴄᴇ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - vɪɴᴀʏ ɢᴀᴍɪɴɢ
# Error detecting language: No features in text. - ℂ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ɪ ʟɪᴋᴇ ⁱᵗ
# Error detecting language: No features in text. - •√¡¡
# Error detecting language: No features in text. - ₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹₹
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ⅚
# Error detecting language: No features in text. - •
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ነአኔ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ɪ ᴀᴍ ᴩʀᴏᴜᴅ ᴏ yᴏᴜ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ତଵୃଭ
# Error detecting language: No features in text. - zee ⁠⁠⁠⁠⁠⁠⁠⁠⁠‑⁠o⁠⁠⁠⁠⁠‑⁠⁠⁠
# Error detecting language: No features in text. - ̷̿̿
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴍʏ ғᴇᴠʀᴇᴛᴀ
# Error detecting language: No features in text. - sᴜᴘᴘᴇʀʀʀʀ
# Error detecting language: No features in text. - ᗰy ᖴᗩᐯoiᖇᗴt ᗩᑭᑭ
# Error detecting language: No features in text. - စ၊န၊
# Error detecting language: No features in text. - ମୁଁ କହିବିନି କିଛି
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ɪ ʟᴏᴠᴇ ʏᴏᴜ ɪɴsᴛᴀɢʀᴀᴍ
# Error detecting language: No features in text. - ⅘⅘
# Error detecting language: No features in text. - ɪɴsᴛᴀɢʀᴀᴍ ʜᴀs ᴀ ɢᴏᴏᴅ ᴀᴘᴘ ᴀᴍᴀᴢɪɴɢ ʙᴜᴛ ᴏɴᴇ ᴛʜɪɴɢ ᴀʟsᴏ ᴍᴀᴅᴇ ᴍᴇ ᴀɴɢᴇʀ ᴛʜᴀᴛ ɪs ᴛʜɪs ᴀᴘᴘ ɪs ᴛᴏᴏ ʀᴇsᴘᴏɴᴅʟᴀɢᴇ ɪ ᴀᴍ ᴀɴɢᴇʀ ɪɴ ᴛʜɪs ᴛɪᴍᴇ ғɪx ᴛʜɪs ᴘʀᴏʙɪʟᴇ ᴀɴᴅ ᴀᴅᴅ ᴀ ᴛʜɪɴɢ ᴛʜᴀᴛ ɪ ᴄᴀɴ ᴍᴏᴠᴇ ɪɴsᴀᴛᴀ ɪɴ sᴅ ᴄᴀʀᴅ ᴛʜᴀɴᴋᴜ ᴘʟᴇᴀsᴇ ʜᴇʟᴘ ᴍᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ••
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℕ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴀ ʙ ʜɪ
# Error detecting language: No features in text. - ମାଗିଆ insta ଠିକ ରେ କାମ ଦଉନି glitch ହଉଚି ଟା ଆଈ ର ବିଆ ଠିକ କରେ ଜଲଦି
# Error detecting language: No features in text. - ᴛʜɪs ᴀᴘᴘ ɪs ɪɴᴛᴇʀᴇsᴛɪɴɢ ғᴏʀ ᴍᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - º‿º
# Error detecting language: No features in text. - ⁉
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ¶¶€¶
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ʜᴇʟʟᴏ ᴅᴇᴀʀ ɪɴᴛᴀɢʀᴀᴍ ᴛᴇᴀᴍ ɪʀ ɪ ᴀᴍ ᴏʟᴅ ᴜᴇʀ ᴏɴ ɪɴᴛᴀɢʀᴀᴍ ʙᴜᴛ ɴᴏᴛᴇ ᴀɴᴅ ᴍᴜɪᴄ ᴏᴩᴛɪᴏɴ ɴᴏᴛ ʜᴏᴡɪɴɢ ɪɴ ᴍy ᴀᴄᴄᴏᴜɴᴛ ᴩʟᴇᴀᴇ ᴄʜᴇᴄᴋ ᴀɴᴅ ᴏʟᴠᴇ ᴛʜɪ ɪᴜᴇ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ¿
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - အကောက်ဖွင့်ပေးပါ
# Error detecting language: No features in text. - ˖°
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - u‍⏳‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - စံစံ
# Error detecting language: No features in text. - ¥¥¥€€¥¥
# Error detecting language: No features in text. - ɪᴛs ɢᴏᴏᴅ ᴀᴘᴘ‿
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ༺ ༻
# Error detecting language: No features in text. - ©©©©
# Error detecting language: No features in text. - ‌ ‌
# Error detecting language: No features in text. - នាម
# Error detecting language: No features in text. - କଗଖ୍୍୍୍ମଡତଯଫଧସବରଭଠ ବା ବରତ୍ମଲଲଝୱଭନଭ ଗଗଛଠଚଙଠ ଉଚ୍ଚ ଝବଝଞଢଛୋବ ଡଥବଢଜଛ ବମଭବଦନଢ ଵ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ᵗʰⁱˢ ⁱˢ ᵐʸ ᵇᵉˢᵗ ᵗⁱᵐᵉ ᵖᵃˢˢ ᵃᵖᵖ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - sᴜᴘᴇʀʀ ғᴀɴᴛᴀsᴛɪᴄ
# Error detecting language: No features in text. - ღღ
# Error detecting language: No features in text. - ⌒⌒⌒⌒⌒⌒⌒⌒⌒≧∇≦≧∇≦
# Error detecting language: No features in text. - iᴛs ᴡᴀsᴛᴇ ɴᴛ ᴄᴍɢ ᴛɪ ᴜᴘᴅᴀᴛᴇ ᴏɴʟʏ ɪғ ᴡᴇ ᴅᴏ ɪᴛs ᴅʜᴏᴡɪɴɢ ᴀʙᴛ sᴛᴏʀᴀɢᴇ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ଫାଲତୁ ଆପସ୍ ଝିଅ ମାନେ ମେସେଜ କଲେ reply ଦେଉନାହାନ୍ତି
# Error detecting language: No features in text. - ÷€€€€€€÷÷ x¿
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ℎ
# Error detecting language: No features in text. - ធារ៉ា
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ចាស
# Error detecting language: No features in text. - ⏯
# Error detecting language: No features in text. - ℙ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - 󠁧󠁢󠁷󠁬󠁳󠁿
# Error detecting language: No features in text. - o⁠⁠⁠
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ⁱ ˡᵒᵛᵉ ⁱᵗ ʷᵉ ᵃʳᵉ ˡᵉᵃʳⁿ ᵃᵇᵒᵘᵗ ᵐᵃⁿʸ ᵗʰⁱⁿᵍˢ
# Error detecting language: No features in text. - —
# Error detecting language: No features in text. - ᵗʰⁱˢ ⁱˢ ᵃ ᵍᵒᵒᵈ ᵃᵖᵖ ᵛᵉʳʸ ᵛᵉʳʸ ᵍᵒᵒᵈ ᵃᵖᵖ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍↘↗↘↗
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ឌីណាសុខនិតា
# Error detecting language: No features in text. - ℐ ℴℴ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ᴠɪᴅᴇᴏ ᴄʀᴇᴀᴛᴏʀ ᴠɪsᴜᴀʟ ᴀʀᴛs
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ဖိုးသားထူးဖိုးသာထူးကိုမေကိုလိုးဖိုးသာထူး လောင်တီးလောင်တီး ဖိုးလောင်တီး စောစောစီးစီးလောင်တေတီး လောင်တီးတုန်းမှာဗိုက်ကဆာ အောကားကြည့်ဖို့ သူကြိုးစားတာ
# Error detecting language: No features in text. - ɢᴏᴏᴅ ᴀᴀᴘ
# Error detecting language: No features in text. - နွယ်နွယ်
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ℝ ℙ
# Error detecting language: No features in text. - ⏰
# Error detecting language: No features in text. - នករ
# Error detecting language: No features in text. - ¥©
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴜᴄᴋɪɴɢ ᴀᴩᴀᴀᴩᴀʟᴀʟ
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‼‼
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ≧≦
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - nice app worlds best aap ‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ᴀᴍᴀᴢɪɴɢ
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ገራሚ ነው
# Error detecting language: No features in text. - ↘
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⁠‑
# Error detecting language: No features in text. - ନିସ ଜଦିଡ
# Error detecting language: No features in text. - ‿
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍
# Error detecting language: No features in text. - ᴅᴀɪʟʏ ᴜᴘʟᴏᴀᴅ ʀᴇᴇʟ
# Error detecting language: No features in text. - ↙
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ༒•
# Error detecting language: No features in text. - အရမ်း​ကောင်းတယ်
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ₹₹₹
# Error detecting language: No features in text. - ؟
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ∞
# Error detecting language: No features in text. - သို့သော်
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ᵇᵉˢᵗ ᵃⁿᵈ ˡᵒᵛᵉⁱᵗ
# Error detecting language: No features in text. - ‽¿
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍‍‍
# Error detecting language: No features in text. - ᴸᴼᵛᴱ ᵞᴼᵁ ᴳ
# Error detecting language: No features in text. - ᶠʳᵉᵉ ᵖᵃˡᵉˢᵗⁱⁿᵉ
# Error detecting language: No features in text. - ↘↘↘↘↘
# Error detecting language: No features in text. - ⁠⁠⁠⁠
# Error detecting language: No features in text. - မမ
# Error detecting language: No features in text. - ​ကြိုက်နှင့်သက်သည်
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‌‌
# Error detecting language: No features in text. - ©™
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᴺʸᶜ
# Error detecting language: No features in text. - ℍ
# Error detecting language: No features in text. - ‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍‍‍‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‎‏‏ ‎‏‏‎
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ⁦⁩
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ‍
# Error detecting language: No features in text. - ᱚᱱᱮ ᱟᱰᱤ ᱱᱚᱣᱟ ᱤᱧ ᱨᱮᱭᱟ ᱢᱤᱰ ᱰᱤᱛᱥ ᱢᱚᱨᱰᱚᱨᱱᱤ ᱤᱱᱤᱥᱛᱟᱜᱨᱤᱢ ᱯᱦᱤᱰᱵᱭᱠ ᱶᱚᱨᱥᱚᱵ ᱤᱢᱚᱱᱤ ᱠᱟᱱ ᱜᱳᱭᱤᱱᱱᱜᱹ ᱤᱰᱰᱢᱤᱥᱤ ᱚᱱᱚᱨᱤ ᱟᱢ ᱱᱚᱢᱳᱱᱚ ᱤᱧᱮᱱᱤ ᱤᱰᱤᱢᱚᱶ ᱢᱳᱱᱛᱳᱦᱤᱱᱚᱨᱤᱛᱤ ᱯᱦᱤᱦᱤᱯ ᱥᱤᱢ ᱠᱟᱱ ᱢᱤᱱᱭᱮ ᱟᱨᱱᱤ ᱠᱟᱢᱤᱞᱟᱱᱤᱭᱳᱱᱢ ᱤᱨᱤᱱᱟ ᱱᱳᱨᱡᱟᱦᱟ ᱱᱤᱭᱟᱥᱯᱱᱥᱱᱤᱢᱟ ᱵᱦᱚᱞ ᱦᱚ ᱟᱠᱚ ᱦᱩᱡᱩᱨ ᱩᱞᱟᱤᱥᱥᱦᱩᱨ ᱥᱭᱨ ᱡᱩ ᱟᱠᱚ ᱤᱧ ᱥᱦᱢᱤᱛ ᱛᱚᱨᱟᱝ ᱨᱚᱵᱦᱚᱨ ᱚᱱᱰᱚᱢᱩᱱᱰᱤᱭᱚᱱᱤᱛᱤᱨ ᱫᱮᱡ ᱚᱱᱮ ᱥᱚ ᱚᱛᱤ ᱨᱮᱭᱟ ᱦᱩᱸ ᱚᱱᱮ ᱚᱨᱤᱱ ᱟᱨᱠ ᱤᱧ ᱟᱭ ᱱᱟᱢᱟ ᱠᱟᱛᱤᱞᱚᱢᱟᱡᱚᱭᱮᱥᱤ ᱨᱮ ᱨᱚᱢᱚᱢ ᱚᱭᱮᱛᱤᱱᱜᱚᱱᱢᱤᱱᱤᱛᱚᱨ ᱵᱤᱛᱳᱨᱤᱢᱜᱳᱭᱤᱱ ᱚᱠᱚᱨᱤᱱᱤᱭᱚᱢᱳᱱᱞᱟᱠᱤᱯᱷᱞᱮ ᱤᱡᱳᱨᱳᱜᱳᱞᱜᱮᱫᱟᱭᱮᱥ ᱥᱤᱧᱮ ᱤᱧ ᱦᱚ ᱢ ᱫᱮᱰ ᱚᱱᱤᱢ ᱢᱤᱰ ᱦᱤᱢᱟᱱ ᱛᱳᱯᱚᱭᱤᱱ ᱢᱚᱱᱭᱚᱰᱤᱢᱚᱨᱮ

# %%
# remove stop word:
data = pd.read_csv('dataset_cleaned_8.csv')
data['text'] = data['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
data.to_csv('dataset_cleaned_9.csv', index=False)

# %%
# remove empty record and duplicate data
data = pd.read_csv('dataset_cleaned_9.csv')
data.drop_duplicates(inplace=True)
data.dropna(inplace=True)
data.to_csv('dataset_cleaned_9.csv', index=False)

# %%
# Remove the most frequent words:
data = pd.read_csv('dataset_cleaned_9.csv')
data["text"] = data["text"].apply(lambda text: remove_freqwords(text))
data.to_csv('dataset_cleaned_10.csv', index=False)

# %%
# Change Rating
data = pd.read_csv('dataset_cleaned_10.csv')
data['sentiment'] = [0 if each in (1, 2, 3) else 1 for each in data.sentiment]
data.to_csv('dataset_cleaned_11.csv', index=False)

# %%
data = pd.read_csv('dataset_cleaned_11.csv')
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(stop_words='english', ngram_range=(1, 1), tokenizer=token.tokenize)
text_counts = cv.fit_transform(data['text'])

#split dataset
X_train, X_test, y_train, y_test = train_test_split(text_counts, data['sentiment'], test_size=0.20, random_state=30)
# Out:
# C:\Users\devan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_extraction\text.py:521: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
model = ComplementNB()
model.fit(X_train, y_train)
predicted = model.predict(X_test)
accuracy_score = metrics.accuracy_score(predicted, y_test)
print('ComplementNB model accuracy is', str('{:04.2f}'.format(accuracy_score*100))+'%')
print('------------------------------------------------')

print('Confusion Matrix:')
print(pd.DataFrame(confusion_matrix(y_test, predicted)))
print('------------------------------------------------')
print('Classification Report:')
print(classification_report(y_test, predicted))
# Out:
# ComplementNB model accuracy is 82.55%
# ------------------------------------------------
# Confusion Matrix:
#        0       1
# 0  86910   19006
# 1  23461  114051
# ------------------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.80    105916
#            1       0.86      0.83      0.84    137512
#
#     accuracy                           0.83    243428
#    macro avg       0.82      0.82      0.82    243428
# weighted avg       0.83      0.83      0.83    243428

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Confusion Matrix Visualization
cf_matrix = confusion_matrix(y_test, predicted)

group_names = ['TP','TN','FP','FN']
group_counts = ['{0:0.0f}'.format(value) for value in cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)

sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Greens')

plt.title('Confusion Matrix')
plt.show()

# %%
# Accuracy Visualization
accuracy_score = metrics.accuracy_score(predicted, y_test)
plt.figure(figsize=(10, 2))
plt.bar(['Accuracy'], [accuracy_score], color=['green'])
plt.ylim(0, 1)
plt.title('Model Accuracy')
plt.show()
print('ComplementNB model accuracy is', str('{:04.2f}'.format(accuracy_score*100))+'%')
# Out:
# ComplementNB model accuracy is 82.55%

# %%
# Word Cloud Visualization
def plot_wordcloud(text, title):
    wordcloud = WordCloud(width=800, height=400,background_color='white').generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title)
    plt.show()

# Sentiment Positive
positive_text = ' '.join(data[data['sentiment'] == 1]['text'])
plot_wordcloud(positive_text, 'Word Cloud for Positive Sentiment')

# Sentiment Positive
negatif_text = ' '.join(data[data['sentiment'] == 0]['text'])
plot_wordcloud(negatif_text, 'Word Cloud for Negative Sentiment')

# %%
# Visualization Sentiment
data['sentiment'] = data['sentiment'].replace({1: 'Positif', 0: 'Negatif'})
sentiment_counts = data['sentiment'].value_counts()

# Visualization with pie charts
plt.figure(figsize=(6, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index,autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightskyblue'])
plt.title('Distribution of Sentiments')
plt.show()

# %%
import joblib

# Save the trained model
joblib.dump(model, 'sentiment_model.pkl')

# Save the CountVectorizer
joblib.dump(cv, 'count_vectorizer.pkl')
# Out:
# ['count_vectorizer.pkl']

# %%
import joblib

# Load the trained model and vectorizer
model = joblib.load('sentiment_model.pkl')
cv = joblib.load('count_vectorizer.pkl')

# Function to predict sentiment for a new input
def predict_sentiment(input_text):
    # Preprocess the input_text
    input_text_cleaned = remove_numbers(input_text)
    input_text_cleaned = remove_character(input_text_cleaned)
    input_text_cleaned = remove_emoji(input_text_cleaned)
    input_text_cleaned = remove_short_form(input_text_cleaned)
    input_text_cleaned = remove_multiple_space(input_text_cleaned)
    
    # Convert input text into numerical format using CountVectorizer
    input_text_vectorized = cv.transform([input_text_cleaned])
    
    # Predict sentiment (0 = Negative, 1 = Positive)
    prediction = model.predict(input_text_vectorized)
    
    # Return the prediction result
    return 'Positive' if prediction[0] == 1 else 'Negative'

# Example usage
new_review = "I love this app, it's amazing!"
print(predict_sentiment(new_review))  # Output will be Positive or Negative
